# %%
#Import Libraries
import pandas as pd
import os
import csv

# %%
os.listdir('./Resources')
# Out:
# ['fafsa-demographics-2006-07.csv',
#  'fafsa-demographics-2007-08.csv',
#  'fafsa-demographics-2008-09.csv',
#  'fafsa-demographics-2009-10.csv',
#  'fafsa-demographics-2010-11.csv',
#  'fafsa-demographics-2011-12.csv',
#  'fafsa-demographics-2012-13.csv',
#  'fafsa-demographics-2013-14.csv',
#  'fafsa-demographics-2014-15.csv',
#  'fafsa-demographics-2015-16.csv',
#  'fafsa-demographics-2016-17.csv',
#  'fafsa-demographics-2017-18.csv']

# %%
for filename in os.listdir('./Resources'):
      demo = pd.read_csv('filename')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-46c8d43a0fa9> in <module>
#       1 for filename in os.listdir('./Resources'):
# ----> 2       demo = pd.read_csv('filename')
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
demo_06 = pd.read_csv('./Resources/fafsa-demographics-2006-07.csv')
demo_06
# Out:
#                                Data Element and Value Initial Application  \
# 0                                                 NaN                2006
# 1                                                 NaN                  Q1
# 2                             Total (Applicant Count)           5,137,719
# 3                                              Gender                 NaN
# 4                                              Female           3,152,173
# 5                                                Male           1,929,308
# 6                                               Blank              56,238
# 7                                                 Age                 NaN
# 8                                          18 or Less             789,687
# 9                                       19 through 24           2,765,076
# 10                                      25 or Greater           1,580,918
# 11                                        Age Unknown               2,038
# ...

# %%
demo_06.iloc[:, 0:7]
# Out:
#                                Data Element and Value Initial Application  \
# 0                                                 NaN                2006
# 1                                                 NaN                  Q1
# 2                             Total (Applicant Count)           5,137,719
# 3                                              Gender                 NaN
# 4                                              Female           3,152,173
# 5                                                Male           1,929,308
# 6                                               Blank              56,238
# 7                                                 Age                 NaN
# 8                                          18 or Less             789,687
# 9                                       19 through 24           2,765,076
# 10                                      25 or Greater           1,580,918
# 11                                        Age Unknown               2,038
# ...

# %%
demo_06_transposed = demo_06.T
demo_06_transposed
# Out:
#                            0    1                        2       3   \
# Data Element and Value    NaN  NaN  Total (Applicant Count)  Gender
# Initial Application      2006   Q1                5,137,719     NaN
# Unnamed: 2                NaN   Q2                3,955,290     NaN
# Unnamed: 3                NaN   Q3                2,730,051     NaN
# Unnamed: 4                NaN   Q4                1,054,763     NaN
# Unnamed: 5               2007   Q5                  776,840     NaN
# Unnamed: 6                NaN  Q6+                  386,661     NaN
# Unnamed: 7              Total  NaN               14,041,324     NaN
# Final Transaction       Total  NaN               14,041,324     NaN
# Unnamed: 9                NaN  NaN                      NaN     NaN
# Unnamed: 10               NaN  NaN                      NaN     NaN
#
#                                4          5        6    7           8   \
# Data Element and Value     Female       Male    Blank  Age  18 or Less
# ...

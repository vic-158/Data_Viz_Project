# %%
#dependecies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import censusdata
import uszipcode
import csv
import json
import gmaps

#import csv file to narrow data search
collegeR = "./resources_Brendan/collegeRanksCSV.csv"

# Census API Key
from goober import api_key
from goober import gkey
c = Census(api_key, year=2010)

# %%
uszipcode = pd.read_

# %%
ranking = pd.read_csv(collegeR)
print(ranking)
# Out:
#                     SCHOOL  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0                Princeton     1     2     1     2     1     1     1     1
# 1                  Harvard     2     1     1     1     1     1     2     2
# 2                     Yale     3     3     3     3     3     3     3     3
# 3                 Stanford     4     4     4     5     5     6     5     4
# 4                 Columbia     9     8     8     4     4     4     4     4
# 5                      MIT     7     4     4     7     5     6     7     7
# 6                     Penn     5     6     4     5     5     8     7     8
# 7                  Chicago     9     8     8     9     5     4     5     4
# 8                  Caltech     5     6     4     7     5    10    10    10
# 9                     Duke     8     8    10     9    10     8     7     8
# 10               Dartmouth    11    11    11     9    11    10    10    11
# ...

# %%
censusdata.search('acs5', 2009, 'label', 'income',)[160:170]
# Out:
# [('B06010_052E',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Foreign born:!!With income:!!$35,000 to $49,999'),
#  ('B06010_052M',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Margin Of Error For!!Foreign born:!!With income:!!$35,000 to $49,999'),
#  ('B06010_053E',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Foreign born:!!With income:!!$50,000 to $64,999'),
#  ('B06010_053M',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Margin Of Error For!!Foreign born:!!With income:!!$50,000 to $64,999'),
#  ('B06010_054E',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Foreign born:!!With income:!!$65,000 to $74,999'),
#  ('B06010_054M',
#   'B06010.  Place of Birth by Individual Income in the United States',
#   'Margin Of Error For!!Foreign born:!!With income:!!$65,000 to $74,999'),
#  ('B06010_055E',
# ...

# %%
#Using Census data 



# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-cfa78824cb5b> in <module>()
# ----> 1 uszipcode.search("income")
#
# TypeError: 'module' object is not callable
